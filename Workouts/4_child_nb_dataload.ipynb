# %%
# %py
import requests

# API URL
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"

# Make API call
response = requests.get(url)

# Validate response
if response.status_code != 200:
    raise Exception(f"API call failed with status code {response.status_code}")

# Store CSV content
csv_data = response.text

# Volume path (Databricks requires dbfs:/ prefix)
volume_path = "dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# Write to volume
dbutils.fs.put(volume_path, csv_data, overwrite=True)

print("CSV successfully written to Databricks Volume")
