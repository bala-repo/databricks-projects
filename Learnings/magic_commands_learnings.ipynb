# %% [markdown]
# ![Inceptez](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %% [markdown]
# Basic magic Commands

# %%
# %run "/Workspace/Users/balachandark1999@gmail.com/databricks-projects/python_foundation_bala_1.py"

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volumewe47_datalake;

# %%
# %sql
create table if not exists default.cities2(id int,city string);
insert into default.cities2 values(3,'Mumbai'),(4,'Lucknow');
select * from cities2;

# %%
# %python
spark.sql("select * from cities2").explain(True)

# %%
# %sql
update cities2 set city='Kolkata' where id=4;

# %%
# %sql
show create table cities2;

# %%
# %sql
from cities2 select *;

# %%
def sqrt(a):
    return a*a
    print("square root of", sqrt(10))
    print ("Learning success")

# %%
from pyspark.sql.session import SparkSession
print(spark)
spark1 = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
print(spark1)
df1 = spark1.read.csv("/Volumes/workspace/default/volumewe47_datalake/patients.csv",header=True)
display(df1)

# %%
df1.where("married='Yes'").write.saveAsTable("default.we47_patients")

# %%
spark.sql("select count(1),InPatient from default.we47_patients group by 2").explain(True)

# %%
spark.read.table("default.we47_patients").show(2)
